# %% [markdown]
# <a href="https://colab.research.google.com/github/irynebbie17-cyber/iris.csv/blob/main/iris_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/1) iris.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
df_cleaned=df.drop_duplicates()

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
print(df['petal_length'].describe())
# Out:
# count    150.000000
# mean       3.758667
# std        1.764420
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal_length, dtype: float64

# %%
df['species']=df['species'].str.lower()

# %%
df.to_csv('cleaned_data.csv',index=False)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print('\nMedians:\n',df.median(numeric_only=True))
# Out:
# Medians:
#  sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# cluster         1.00
# dtype: float64

# %%
plt.figure(figsize=(8,5))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(data=df,x='sepal_length',y='sepal_width',hue='petal_length')
plt.title('Relationship between Sepal Length and Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.savefig('sepal_length_width_petal_length_scatter.png')
plt.close()

# %%
corr_matrix=df.select_dtypes(include=['float64','int64']).corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(data=df,x='petal_length',kde=True,color='teal')
plt.title('Distribution of Petal Length')
plt.xlabel('Petal Length')
plt.ylabel('Frequency')
plt.savefig('petal_length_distribution_hist.png')
plt.close()

# %%
plt.figure(figsize=(8,5))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.title('Iris Dataset Corelation Analysis',fontsize=15)
plt.savefig('iris_correlation_heatmap.png')
plt.close()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
df=sns.load_dataset('iris')
plt.figure(figsize=(8,5))
sns.boxplot(data = df, x='petal_length', color='teal')
plt.title('Distribution of Petal Length')
plt.xlabel('Box plot of the Petal Length(cm)')
plt.ylabel('Frequeny')
plt.savefig('petal_length_boxplot.png')
plt.close()

# %%
mean_values=df.mean(numeric_only=True)
print('Mean for each feature')
print(mean_values)
# Out:
# Mean for each feature
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# cluster         0.926667
# dtype: float64

# %%
mode_df = df.mode(numeric_only=True)
print('Mode for each feature')
print(mode_df.iloc[0])
# Out:
# Mode for each feature
# sepal_length    5.0
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.2
# cluster         2.0
# Name: 0, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,5))
sns.scatterplot(data=df,x='sepal_length',y='sepal_width',hue='species')
plt.title('Relationship between Sepal Length and Width')
plt.savefig('sepal_length_width_species_scatter.png')
plt.close()

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df,x='species',y='petal_width',estimator='mean')
plt.title('Average Petal Width by Species')
plt.savefig('average_petal_width_by_species_barplot.png')
plt.close()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
x = df[['petal_length']]
y = df['petal_width']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model = LinearRegression()
model.fit (x_train, y_train)
y_pred = model.predict(x_test)
print(f'R-squared: {r2_score(y_test,y_pred):.2f}')
# Out:
# R-squared: 0.93

# %%
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose
dates = pd.date_range(start='2023-01-01',periods=100,freq='D')
values = [i +(i%7)for i in range(100)]
ts_data = pd.Series(values, index = dates)
result = seasonal_decompose(ts_data,model='additive', period=7)
result.plot()
plt.show()

# %%
from sklearn.cluster import KMeans
x_clustering = df.drop('species', axis=1)
kmeans = KMeans(n_clusters=3,random_state=42,n_init='auto')
df['cluster'] = kmeans.fit_predict(x_clustering)
sns.scatterplot(data=df,x='petal_length',y='petal_width',hue='cluster', palette='viridis')
plt.title('Clustering Results')
plt.savefig('kmeans_clustering_petal_length_width.png')
plt.close()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features = df.drop('species', axis=1)
scaled_features = scaler.fit_transform(features)
wcss = []
for i in range(1,11):
     kmeans = KMeans(n_clusters=i,init='k-means++',random_state=42,n_init='auto')
     kmeans.fit(scaled_features)
     wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss,marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.savefig('kmeans_elbow_method.png')
plt.close()

# %%
from sklearn.cluster import KMeans
import seaborn as sns
import matplotlib.pyplot as plt
kmeans = KMeans(n_clusters= 3, init='k-means++',random_state=42,n_init='auto')
df['cluster'] = kmeans.fit_predict(scaled_features)
sns.scatterplot(data=df,x='petal_length',y='petal_width',hue='cluster',palette='viridis')
plt.title('K-Means Clustering Results')
plt.savefig('kmeans_clustering_results.png')
plt.close()

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
x=df.drop(['species','cluster'],axis=1)
y=df['species']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
models = {
    'Random Forest': RandomForestClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Logistic Regression': LogisticRegression()
}
for name, model in models.items():
  model.fit(x_train,y_train)
  y_pred = model.predict(x_test)
  print(f'{name} Accuracy: {accuracy_score(y_test,y_pred):.2f}')
  print(classification_report(y_test,y_pred))
  param_grid = {
      'n_estimators': [10,50,100],
      'max_depth': [None,5,10]

  }
  grid_search = GridSearchCV(RandomForestClassifier(),param_grid,cv=5)
  grid_search.fit(x_train,y_train)
  print('Best Parameters:',grid_search.best_params_)
# Out:
# Random Forest Accuracy: 1.00
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# Best Parameters: {'max_depth': 5, 'n_estimators': 100}
# Decision Tree Accuracy: 1.00
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# Best Parameters: {'max_depth': None, 'n_estimators': 50}
# ...

# %%
import joblib
best_model = grid_search.best_estimator_
joblib.dump(best_model,'iris_model.joblib')
print('Model saved successfully')
# Out:
# Model saved successfully

# %%
df.to_csv('iris_data_for_bi.csv',index=False)

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("punkt")
data = {
 'Review':[
    'Best purchase I have made this year, highly recommended!'
    'I am really disappointed with customer service']}
df = pd.DataFrame(data)
def clean_text(text):
  text = re.sub(r'[^a-zA-Z\s]', '',text)
  text = text.lower()
  stop_words = set(stopwords.words('english'))
  words = text.split()
  cleaned_words = [w for w in words if w not in stop_words]
  return "".join(cleaned_words)
  df['Cleaned_Review'] = df['Review'].apply(clean_text)
  print(df[['Review','Cleaned_Review']])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("punkt")
data = {
    'Review' : [
        'Best purchase I have made this year, highly recommended!',
        'I am really disappointed with customer service.'
    ]
}
df = pd.DataFrame(data)
def clean_text(text):
 text = re.sub(r'[^a-zA-Z\s]', '', text)
 text = text.lower()
 stop_words = set(stopwords.words('english'))
 words = text.split()
 cleaned_words = [w for w in words if w not in stop_words]
 return " ".join(cleaned_words)
df['Cleaned_Review'] = df['Review'].apply(clean_text)
print(df[['Review', 'Cleaned_Review']])
from textblob import TextBlob
def get_sentiment(text):
 analysis = TextBlob(text)
 return analysis.sentiment.polarity
def get_category(score):
 if score > 0:
  return 'Positive'
 elif score < 0:
  return 'Negative'
 else:
  return 'Neutral'
df['Score'] = df['Cleaned_Review'].apply(get_sentiment)
df['Sentiment'] = df['Score'].apply(get_category)
print(df[['Review','Cleaned_Review','Score','Sentiment']])
# Out:
#                                               Review  \
# 0  Best purchase I have made this year, highly re...
# 1    I am really disappointed with customer service.
#
#                                Cleaned_Review
# 0  best purchase made year highly recommended
# 1        really disappointed customer service
#                                               Review  \
# 0  Best purchase I have made this year, highly re...
# 1    I am really disappointed with customer service.
#
#                                Cleaned_Review  Score Sentiment
# 0  best purchase made year highly recommended   0.58  Positive
# 1        really disappointed customer service  -0.75  Negative
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
import re
import pandas as pd
from nltk.corpus import stopwords
import nltk
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("punkt")

data = {
    'Review' : [
        'Best purchase I have made this year, highly recommended!',
        'I am really disappointed with customer service.'
    ]
}
df_sentiment = pd.DataFrame(data)

def clean_text(text):
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = text.lower()
    stop_words = set(stopwords.words('english'))
    words = text.split()
    cleaned_words = [w for w in words if w not in stop_words]
    return " ".join(cleaned_words)

df_sentiment['Cleaned_Review'] = df_sentiment['Review'].apply(clean_text)

def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

def get_category(score):
    if score > 0:
        return 'Positive'
    elif score < 0:
        return 'Negative'
    else:
        return 'Neutral'

df_sentiment['Score'] = df_sentiment['Cleaned_Review'].apply(get_sentiment)
df_sentiment['Sentiment'] = df_sentiment['Score'].apply(get_category)

sns.set(style='whitegrid')
plt.figure(figsize=(8,5))
sns.countplot(data=df_sentiment,x='Sentiment',palette={'Positive':'green','Negative':'red','Neutral':'gray'})
plt.title('Distribution of Sentiment')
plt.xlabel('Sentiment Category',fontsize=12)
plt.ylabel('Frequency',fontsize=12)
plt.savefig('sentiment_distribution_countplot.png')
plt.close()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /tmp/ipykernel_475/2504438729.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_sentiment,x='Sentiment',palette={'Positive':'green','Negative':'red','Neutral':'gray'})

# %%
pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
import nltk
from nltk.corpus import stopwords
from textblob import TextBlob
import re
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("punkt")

data = {
    'Review' : [
        'Best purchase I have made this year, highly recommended!',
        'I am really disappointed with customer service.'
    ]
}
df_sentiment = pd.DataFrame(data)

def clean_text(text):
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = text.lower()
    stop_words = set(stopwords.words('english'))
    words = text.split()
    cleaned_words = [w for w in words if w not in stop_words]
    return " ".join(cleaned_words)

df_sentiment['Cleaned_Review'] = df_sentiment['Review'].apply(clean_text)

text = ' '.join(review for review in df_sentiment.Cleaned_Review)
wordcloud = WordCloud(width=800,height=400,background_color='white').generate(text)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.title('Most Frequent Words in Reviews',fontsize=15)
plt.savefig('wordcloud_reviews.png')
plt.close()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df.to_csv('nlp_sentiment_results.csv', index=False)
print('Task 3 Complete! File saved as nlp_sentiment_results.csv')
# Out:
# Task 3 Complete! File saved as nlp_sentiment_results.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
